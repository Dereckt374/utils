# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %%
wiki1=pd.read_html("https://fr.wikipedia.org/wiki/Liste_des_sondes_spatiales_qui_ont_atterri_sur_un_corps_extraterrestre")

# %%
len(wiki1)
# Out:
# 4

# %%
wiki1[2]
# Out:
#                     Mission       Pays/agence              Date  \
# 0                    Mars 2  Union soviétique  27 novembre 1971
# 1                    Mars 3  Union soviétique   2 décembre 1971
# 2                    Mars 6  Union soviétique      12 mars 1974
# 3                  Viking 1        États-Unis   20 juillet 1976
# 4                  Viking 2        États-Unis  3 septembre 1976
# 5           Mars Pathfinder        États-Unis    4 juillet 1997
# 6         Mars Polar Lander        États-Unis   3 décembre 1999
# 7                  Beagle 2               ESA  25 décembre 2003
# 8              MER-A Spirit        États-Unis    3 janvier 2004
# 9         MER-B Opportunity        États-Unis   25 janvier 2004
# 10                  Phoenix        États-Unis       25 mai 2008
# 11  Mars Science Laboratory        États-Unis       6 août 2012
# 12             Schiaparelli               ESA   19 octobre 2016
# 13                  Insight        États-Unis  27 novembre 2018
# ...
