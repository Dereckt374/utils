# %%
import os

# %%
path_in = r'/home/virgil/Nextcloud/ROBUSTA-3U/ROBUSTA-3A/R3A-DATA/R3A-DATA-IO/0_Pass Report'

# %%
lst_files = []
for i in os.listdir(path_in):
    if i.find('.txt') > 0 : lst_files.append(i)
for i in enumerate(lst_files) : print(i)
# Out:
# (0, 'ROB3A-DATA-IO_20240912_2302_UTC_Pass Operation Report.txt')
# (1, 'ROB3A-DATA-IO_20240812_1520_Pass Operation Report.txt')
# (2, 'ROB3A-DATA-IO_20241009_1423_UTC_Pass Operation Report.txt')
# (3, 'ROB3A-DATA-IO_20240812_1341_Pass Operation Report.txt')
# (4, 'ROB3A-DATA-IO_20240718_1501_Pass Operation Report.txt')
# (5, 'ROB3A-DATA-IO_20240911_2119_UTC_Pass Operation Report.txt')
# (6, 'ROB3A-DATA-IO_20240805_1629UTC_Pass Operation Report.txt')
# (7, 'ROB3A-DATA-IO_20240718_1642_Pass Operation Report.txt')
# (8, 'ROB3A-DATA-IO_20240807_1459_Pass Operation Report.txt')
# (9, 'ROB3A-DATA-IO_20240919_2146_UTC_Pass Operation Report.txt')
# (10, 'ROB3A-DATA-IO_20240916_0554_UTC_Pass Operation Report.txt')
# (11, 'ROB3A-DATA-IO_20241009_1604_UTC_Pass Operation Report.txt')
# (12, 'ROB3A-DATA-IO_20240731_0925_UTC_Pass Operation Report.txt')
# (13, 'ROB3A-DATA-IO_20240726_1042_UTC_Pass Operation Report.txt')
# (14, 'ROB3A-DATA-IO_20241003_1548_UTC_Pass Operation Report.txt')
# ...

# %%
txt_to_be_found = 'radio'

# %%
for i in lst_files:
    path_tot = os.path.join(path_in,i)
    lst = [line.strip() for line in open(path_tot)]
    txt = ''.join(lst)
    txt = txt.lower()
    if txt.find(txt_to_be_found) > 0:
        print(i)
# Out:
# ROB3A-DATA-IO_20240912_2302_UTC_Pass Operation Report.txt
