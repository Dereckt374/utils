# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Radat plot

# %%
# Libraries
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 

# number of variable
categories = ['G', 'D','A','E', 'B', 'F#', 'Db', 'Ab', 'Eb', 'Bb', 'F', 'C'][::-1]
N = len(categories)
values = [0] * (N)
index = []
notes = ['C', 'E', 'G', 'B']

for i in notes:
    try : 
          index.append(categories.index(i))
          print(f'note {i} trouvée en index {index[-1]}')
          values[index[-1]] = 1
    except :
         ...
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
# angles += angles[:1]
# angles_note = [angles[i] for i in index]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# Draw one axe per variable + add labels
plt.xticks(angles, categories, color='black', size=15)
 
# Draw ylabels
ax.set_theta_zero_location('N')
ax.set_rlabel_position(0)
# plt.yticks([10,20,30], ["10","20","30"], color="grey", size=7)
# plt.ylim(0,40)
ax.set_yticklabels([])
 
df = pd.DataFrame({'notes': categories, 'value' :values , 'angle' : angles})
df = df[df['value']==1]
df = df.append(df.iloc[0])
# pd.concat([df.T, df.iloc[0]], axis = 1).T

# Plot data
ax.plot(df['angle'] , df['value'], marker = 'o', linewidth=1, linestyle='solid')
 
# Fill area
# ax.fill(angles, values, 'b', alpha=0.1)
ax.fill(df['angle'] , df['value'], alpha=0.5)

# plt.plot(angles_note, [1.5]*len(notes) , marker='o', color='b', linewidth=2)
# Show the graph
plt.show()
# Out:
# note C trouvée en index 0
# note E trouvée en index 8
# note G trouvée en index 11
# note B trouvée en index 7
# C:\Users\Virgil MESLE\AppData\Local\Temp\ipykernel_23756\1866203386.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df.iloc[0])

# %%
from matplotlib import pyplot as plt

ra = [0,30,60,90,120,150,180,210,240,270,300,330] 
ra = [x/180.0*np.pi for x in ra]

dec = [1.5] * (len(ra))

ax = plt.subplot(111, projection='polar')
# plt.polar(ra, dec, 'ok')
plt.plot(ra,dec , marker='o', color='olive', linewidth=2)
ax.set_yticklabels([])
# Out:
# [Text(0, 0.2, ''),
#  Text(0, 0.4, ''),
#  Text(0, 0.6000000000000001, ''),
#  Text(0, 0.8, ''),
#  Text(0, 1.0, ''),
#  Text(0, 1.2000000000000002, ''),
#  Text(0, 1.4000000000000001, ''),
#  Text(0, 1.6, '')]

# %% [markdown]
# ## Polar plot

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8), subplot_kw=dict(polar=True, zorder=1))
fig.subplots_adjust(left=0.3, right=0.7, top=0.7, bottom=0.3)

sizes = [32, 20, 15, 10, 10, 8, 5]
labels = 'apple', 'banana', 'cherry', 'durian', 'elderberries', 'figs', 'grapes'

ax2 = fig.add_subplot(111, label="pie axes", zorder=0)
d = ax2.pie(sizes, labels=labels, radius=1.75, autopct='%1.1f%%', startangle=90, labeldistance=1.05)
ax2.set(aspect="equal")
plt.show()

# %%
r = np.arange(0, 2, 0.01)
theta = 2 * np.pi * r

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.plot(theta, r)
ax.set_rmax(2)
ax.set_rticks([0.5, 1, 1.5, 2])  # Less radial ticks
ax.set_rlabel_position(-22.5)  # Move radial labels away from plotted line
ax.grid(True)

ax.set_title("A line plot on a polar axis", va='bottom')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8], polar=True)
# ax.invert_yaxis()
ax.set_theta_zero_location('N')
# ax.set_rlim(90, 0, 1)
ax.set_rlim(bottom=0, top=90)
# Note: you must set the end of arange to be slightly larger than 90 or it won't include 90
ax.set_yticks(np.arange(0, 91, 10))
ax.set_yticklabels(ax.get_yticks()[::-1])
ax.plot([0,10,4], 90-np.array([12,13,40]), linestyle='', marker='.')
fig.show()
# Out:
# C:\Users\Virgil MESLE\AppData\Local\Temp\ipykernel_25632\3617618629.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ## Custom style

# %%
matplotlib.style.library
# Out:
# {'bmh': RcParams({'axes.edgecolor': '#bcbcbc',
#            'axes.facecolor': '#eeeeee',
#            'axes.grid': True,
#            'axes.labelsize': 'large',
#            'axes.prop_cycle': cycler('color', ['#348ABD', '#A60628', '#7A68A6', '#467821', '#D55E00', '#CC79A7', '#56B4E9', '#009E73', '#F0E442', '#0072B2']),
#            'axes.titlesize': 'x-large',
#            'grid.color': '#b2b2b2',
#            'grid.linestyle': '--',
#            'grid.linewidth': 0.5,
#            'legend.fancybox': True,
#            'lines.linewidth': 2.0,
#            'mathtext.fontset': 'cm',
#            'patch.antialiased': True,
#            'patch.edgecolor': '#eeeeee',
#            'patch.facecolor': 'blue',
#            'patch.linewidth': 0.5,
#            'text.hinting_factor': 8,
#            'xtick.direction': 'in',
#            'ytick.direction': 'in'}),
#  'classic': RcParams({'_internal.classic_mode': True,
#            'agg.path.chunksize': 0,
#            'animation.bitrate': -1,
# ...

# %%
matplotlib.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# plt.style.use(<style-name>)
# plt.style.use('polar_context.mplstyle')
plt.style.use('fast')

# %%
plt.plot([0,1,2,3], [5,6,7,8])

# %%
class CustomPlotting():
    def __enter__(self):
        import matplotlib.pyplot as plt 
        plt.rcParams["figure.figsize"] = [15,10]
        plt.rcParams['font.size'] = '20'
        return self

    def __exit__(self, exc_type, exc_val, exc_tb):
        plt.plot()
        plt.close()
        return(self)

# %%
import matplotlib
import matplotlib.pyplot as plt 
matplotlib.matplotlib_fname()
# Out:
# 'C:\\Users\\Virgil MESLE\\AppData\\Roaming\\Python\\Python310\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %%
path_custom_style = r"C:\Users\Virgil MESLE\Downloads\results\doc\style_1.mplstyle"
plt.style.use(path_custom_style)

# %%
with plt.style.context(path_custom_style):  
	plt.plot([1, 2, 3, 4])
