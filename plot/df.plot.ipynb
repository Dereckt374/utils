# %%
import pandas as pd

# %% [markdown]
# source : https://medium.com/analytics-vidhya/dummy-dataframes-5672216d636

# %%
df = pd.util.testing.makeDataFrame()

# %%
df.plot(kind='line', subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
df.plot(kind='line', subplots=True, layout=(2,2), figsize = (15,10))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
df.plot(kind='line', subplots=True, layout=(2,2), figsize = (15,10), grid=True, title = 'Bonjour',fontsize = 15 )
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df[['A', 'B']].plot(y = 'B', secondary_y =True, legend=True)
# Out:
# <AxesSubplot:>
